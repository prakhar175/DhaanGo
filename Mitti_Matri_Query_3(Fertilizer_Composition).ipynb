# %%
GROQ_API_KEY="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"

# %%
url = 'https://api.devnagri.com/machine-translation/v2/translate'

# %%
import os
import requests
from groq import Groq

memory=[]

a = 0
b=0

client = Groq(
api_key=GROQ_API_KEY,
)
if b==0:
Query = input("Give Crop ")
chat_completion = client.chat.completions.create(
messages=[
{
"role": "user",
"content": f"for the given crop {Query},please give the type of fertilizer and pesticides to be used for best yield, try showing the composition.",
}
],
model="llama3-8b-8192",
        )
       

help=chat_completion.choices[0].message.content
data = {
'key': 'devnagri_a52a6a788d8311ef972f4a279c6d377c',  # Replace with your actual API key
'sentence': help,
'src_lang': 'en',
'dest_lang': 'hi'
}

response = requests.post(url, data=data)

ans = response.json()
answer = ans["translated_text"]
print(answer)
# Out:
# Give Crop  mustard
# सरसों की फसल के लिए, सर्वोत्तम उपज के लिए निम्नलिखित प्रकार के उर्वरक और कीटनाशकों की सिफारिश की जाती हैः
#
# * * उर्वरकः * *
#
# 1. * * यौगिक उर्वरकः * * सरसों की फसल के लिए नाइट्रोजन, फॉस्फोरस और पोटेशियम के संतुलित आहार की आवश्यकता होती है। निम्नलिखित संरचना वाले यौगिक उर्वरक का उपयोग किया जा सकता हैः
# 	* एनपीके 15:15:15 (नाइट्रोजन-फॉस्फोरस-पोटेशियम) या 20:20:20
# 	* उदाहरण: कोरोमंडल डी-अमोनियम फॉस्फेट (14:20:14), इफको पेंटा-फॉर्म (15:15:15)
# 2. * * जैविक उर्वरकः * * सरसों की फसल भी जैविक उर्वरकों के प्रति अच्छी प्रतिक्रिया देती है, जो मृदा बायोटा को बढ़ावा देते हैं और मृदा संरचना में सुधार करते हैं। कुछ उदाहरणों में शामिल हैंः
# 	* वर्मीकम्पोस्ट (वर्मी-कम्पोस्ट): 1 से 2 टन प्रति एकड़
# 	* फार्म यार्ड खाद (एफवाईएम): 2 से 3 टन प्रति एकड़
# 	* हरी खाद: 1 से 2 टन प्रति एकड़
#
# * कीटनाशकः * *
#
# 1. * * हर्बिसाइड्सः * * खरपतवार नियंत्रण के लिएः
# 	* प्री-प्लांटिंग एप्लिकेशन के लिए 1.5-2.0 किग्रा/ए (1.5-2.0 किग्रा/हेक्टेयर) पर ग्लाइफोसेट (राउंडअप)
# 	* प्री-इमर्जेंस एप्लिकेशन के लिए 0.5-1.0 किग्रा/ए (0.5-1.0 किग्रा/हेक्टेयर) पर 2,4-डी (2,4-डाइक्लोरोफेनोक्सीसेटिक एसिड)
# 2. * * कीटनाशकः * * कीट नियंत्रण के लिएः
# 	* एफिड्स को नियंत्रित करने के लिए क्लोरपाइरिफोस (दुर्स्बान) 0.05-0.10 किग्रा/ए (0.05-0.10 किग्रा/हेक्टेयर) पर, व्हाइटफ्लाइज, और थ्रीप्स
# 	* कॉबीज मॉथ और सरसों एफिड जैसे लेपिडोप्टेरन कीटों को नियंत्रित करने के लिए 0.05-0.10 किग्रा/ए (0.05-0.10 किग्रा/हेक्टेयर) पर स्पिनोसल (प्रतिनिधि)
# 3. * * कवकनाशकः * * रोग नियंत्रण के लिएः
# 	* लीफ स्पॉट, जंग और डाउनी फफूंदी जैसी बीमारियों को नियंत्रित करने के लिए मैनकोज़ेब (डिथेन एम-45) 0.5-1.0 किग्रा/ए (0.5-1.0 किग्रा/हेक्टेयर) पर
#
# * * नोटः * *
#
# 1. कीटनाशकों के लिए हमेशा लेबल निर्देशों और अनुशंसित आवेदन दरों का पालन करें।
# 2. कीटनाशकों के उपयोग को कम करने और पारिस्थितिक संतुलन को बढ़ावा देने के लिए एकीकृत कीट प्रबंधन (आईपीएम) रणनीतियों का उपयोग करें।
# 3. मिट्टी के प्रकार, फसल के चरण और मौसम की स्थिति के अनुसार उर्वरक और कीटनाशकों का प्रयोग किया जाना चाहिए।
# 4. उर्वरक और कीटनाशक अनुप्रयोगों को समायोजित करने के लिए मृदा परीक्षण और फसल कीटों और बीमारियों की नियमित निगरानी आवश्यक है।
#
# विशिष्ट सिफारिशों के लिए स्थानीय अधिकारियों, विस्तार सेवाओं या विशेषज्ञों से परामर्श करना याद रखें, क्योंकि मिट्टी और जलवायु की स्थिति अलग-अलग हो सकती है।
# 0/1 0
# Mai Aapki Kya Sahayta Kar Sakti Hu ye mai kaha se le sakta hu
# दी गई जानकारी के आधार पर, सरसों की फसल के लिए, मैं सर्वोत्तम उपज के लिए निम्नलिखित प्रकार के उर्वरक और कीटनाशकों का सुझाव दे सकता हूंः
#
# * * उर्वरकः * *
#
# * * * यौगिक उर्वरक: * * सरसों की फसल के लिए नाइट्रोजन, फॉस्फोरस और पोटेशियम के संतुलित आहार की आवश्यकता होती है। निम्नलिखित संरचना वाले यौगिक उर्वरक का उपयोग किया जा सकता हैः
# 	+ एनपीके 15:15:15 (नाइट्रोजन-फॉस्फोरस-पोटेशियम) या 20:20:20
# 	+ उदाहरण: कोरोमंडल डी-अमोनियम फॉस्फेट (14:20:14), इफको पेंटा-फॉर्म (15:15:15)
#
# या, यदि आप जैविक उर्वरकों को पसंद करते हैंः
#
# * * * जैविक उर्वरकः * * सरसों की फसल भी जैविक उर्वरकों के प्रति अच्छी प्रतिक्रिया देती है, जो मृदा बायोटा को बढ़ावा देते हैं और मृदा संरचना में सुधार करते हैं। कुछ उदाहरणों में शामिल हैंः
# 	+ वर्मीकम्पोस्ट (वर्मी-कम्पोस्ट): 1 से 2 टन प्रति एकड़
# 	+ फार्म यार्ड खाद (एफवाईएम): 2 से 3 टन प्रति एकड़
# 	+ हरी खाद: 1 से 2 टन प्रति एकड़
#
# * कीटनाशकः * *
#
# * * * हर्बिसाइड्सः * * खरपतवार नियंत्रण के लिएः
# 	+ प्री-प्लांटिंग एप्लिकेशन के लिए 1.5-2.0 किलोग्राम/ए (1.5-2.0 किलोग्राम/हेक्टेयर) पर ग्लाइफोसेट (राउंडअप)
# 	+ 2,4-डी (2,4-डाइक्लोरोफेनोक्सीसेटिक एसिड) पूर्व-उद्भव अनुप्रयोग के लिए 0.5-1.0 किग्रा/ए (0.5-1.0 किग्रा/हेक्टेयर) पर
# * * * कीटनाशकः * * कीट नियंत्रण के लिएः
# 	एफिड्स को नियंत्रित करने के लिए + क्लोरपाइरिफोस (डर्सबान) 0.05-0.10 किलोग्राम/ए (0.05-0.10 किलोग्राम/हेक्टेयर) पर, व्हाइटफ्लाइज, और थ्रीप्स
# 	+ स्पिनोसल (डेलीगेट) को 0.05-0.10 किग्रा/ए (0.05-0.10 किग्रा/हेक्टेयर) पर लेपिडोप्टेरन कीटों जैसे कि पत्तागोभी पतंग और सरसों एफिड को नियंत्रित करने के लिए
# * * * कवकनाशकः * * रोग नियंत्रण के लिएः
# 	+ लीफ स्पॉट जैसी बीमारियों को नियंत्रित करने के लिए मैनकोज़ेब (डिथेन एम-45) 0.5-1.0 किग्रा/ए (0.5-1.0 किग्रा/हेक्टेयर) पर, जंग लगना, और डाउनी फफूंदी
#
# कृपया ध्यान दें कि कीटनाशकों के लिए लेबल निर्देशों और अनुशंसित आवेदन दरों का पालन करना और कीटनाशकों के उपयोग को कम करने और पारिस्थितिक संतुलन को बढ़ावा देने के लिए एकीकृत कीट प्रबंधन (आईपीएम) रणनीतियों का उपयोग करना आवश्यक है।
#
# चूंकि मिट्टी और जलवायु की स्थिति अलग-अलग हो सकती है, इसलिए मैं विशिष्ट सिफारिशों के लिए स्थानीय अधिकारियों, विस्तार सेवाओं या विशेषज्ञों से परामर्श करने की सलाह देता हूं।
# 0/1 0
# Mai Aapki Kya Sahayta Kar Sakti Hu from where cani buy such a fertilizer
# जानकारी के आधार पर, सरसों की फसल के लिए, सर्वोत्तम उपज के लिए आप निम्नलिखित प्रकार के उर्वरकों का उपयोग कर सकते हैंः
#
# * * यौगिक उर्वरकः * *
#
# * एनपीके 15:15:15 (नाइट्रोजन-फॉस्फोरस-पोटेशियम) या 20:20:20
# 	+ उदाहरण: कोरोमंडल डी-अमोनियम फॉस्फेट (14:20:14), इफको पेंटा-फॉर्म (15:15:15)
#
# * * जैविक उर्वरकः * *
#
# * वर्मीकम्पोस्ट (वर्मी-कम्पोस्ट): 1 से 2 टन प्रति एकड़
# * फार्म यार्ड खाद (एफवाईएम): 2 से 3 टन प्रति एकड़
# * हरी खाद: 1 से 2 टन प्रति एकड़
#
# कीटनाशकों के लिए, आप निम्नलिखित का उपयोग कर सकते हैंः
#
# * * हर्बिसाइड्सः * *
#
# * प्री-प्लांटिंग एप्लिकेशन के लिए 1.5-2.0 किग्रा/ए (1.5-2.0 किग्रा/हेक्टेयर) पर ग्लाइफोसेट (राउंडअप)
# * 2,4-डी (2),4-डायक्लोरोफेनोक्सीसेटिक एसिड) 0.5-1.0 किग्रा/ए (0.5-1.0 किग्रा/हेक्टेयर) पर पूर्व-उद्भव अनुप्रयोग के लिए
#
# * * कीटनाशकः * *
#
# * एफिड्स को नियंत्रित करने के लिए क्लोरपाइरिफोस (डर्सबान) 0.05-0.10 किग्रा/ए (0.05-0.10 किग्रा/हेक्टेयर) पर, व्हाइटफ्लाइज, और थ्रीप्स
# * कोबीज पतंग और सरसों एफिड जैसे लेपिडोप्टेरन कीटों को नियंत्रित करने के लिए 0.05-0.10 किग्रा/ए (0.05-0.10 किग्रा/हेक्टेयर) पर स्पाइनोसल (प्रतिनिधि)
#
# * * कवकनाशकः * *
#
# * लीफ स्पॉट जैसी बीमारियों को नियंत्रित करने के लिए मैनकोजेब (डिथेन एम-45) 0.5-1.0 किग्रा/ए (0.5-1.0 किग्रा/हेक्टेयर) पर, जंग लगना, और डाउनी फफूंदी
# 0/1 1
